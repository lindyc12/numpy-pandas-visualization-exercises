# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = range(-10, 10)
y = [(x**2 - x + 2) for x in x]


plt.plot(x,y)

# %%
#2 
x = np.linspace(0,50)
y = np.sqrt(x)

plt.plot(x,y)

# %%
#2

x = range(-50, 50)
y = [n **3 for n in x]

plt.plot(x,y)
